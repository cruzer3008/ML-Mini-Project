# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('DelayedFlights.csv')

# %%
df.shape
# Out:
# (1936758, 30)

# %%
df.describe()
# Out:
#          Unnamed: 0       Year         Month    DayofMonth     DayOfWeek  \
# count  1.936758e+06  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06
# mean   3.341651e+06     2008.0  6.111106e+00  1.575347e+01  3.984827e+00
# std    2.066065e+06        0.0  3.482546e+00  8.776272e+00  1.995966e+00
# min    0.000000e+00     2008.0  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.517452e+06     2008.0  3.000000e+00  8.000000e+00  2.000000e+00
# 50%    3.242558e+06     2008.0  6.000000e+00  1.600000e+01  4.000000e+00
# 75%    4.972467e+06     2008.0  9.000000e+00  2.300000e+01  6.000000e+00
# max    7.009727e+06     2008.0  1.200000e+01  3.100000e+01  7.000000e+00
#
#             DepTime    CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.936758e+06  1.936758e+06  1.929648e+06  1.936758e+06  1.936758e+06
# mean   1.518534e+03  1.467473e+03  1.610141e+03  1.634225e+03  2.184263e+03
# std    4.504853e+02  4.247668e+02  5.481781e+02  4.646347e+02  1.944702e+03
# ...

# %%
# Name: Description
# Year: 2008
# Month: 1-12
# DayofMonth: 1-31
# DayOfWeek: 1 (Monday) - 7 (Sunday)
# DepTime: actual departure time (local, hhmm)
# CRSDepTime: scheduled departure time (local, hhmm)
# ArrTime: actual arrival time (local, hhmm)
# CRSArrTime: scheduled arrival time (local, hhmm)
# UniqueCarrier: unique carrier code
# FlightNum: flight number
# TailNum: plane tail number
# ActualElapsedTime: in minutes
# CRSElapsedTime: in minutes
# AirTime: in minutes
# ArrDelay: arrival delay, in minutes
# DepDelay: departure delay, in minutes
# Origin: origin IATA airport code
# Dest: destination IATA airport code
# Distance: in miles
# TaxiIn: taxi in time, in minutes
# TaxiOut: taxi out time in minutes
# Cancelled: was the flight cancelled?
# CancellationCode: reason for cancellation (A = carrier, B = weather, C = NAS, D = security)
# Diverted: 1 = yes, 0 = no
# CarrierDelay: in minutes
# WeatherDelay: in minutes
# NASDelay: in minutes
# SecurityDelay: in minutes
# LateAircraftDelay: in minutes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 30 columns):
# Unnamed: 0           int64
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier        ...          TaxiIn TaxiOut  \
# 0   2211.0        2225            WN        ...             4.0     8.0
# 1   1002.0        1000            WN        ...             5.0    10.0
# 2    804.0         750            WN        ...             3.0    17.0
# 3   1959.0        1925            WN        ...             3.0    10.0
# 4   2121.0        2110            WN        ...             4.0    10.0
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
df = df[['Month', 'DayofMonth', 'DayOfWeek','FlightNum','CRSDepTime', 'DepDelay', 'TaxiOut', 'Distance','CRSArrTime','ArrDelay']]

# %%
df.shape
# Out:
# (1936758, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 10 columns):
# Month         int64
# DayofMonth    int64
# DayOfWeek     int64
# FlightNum     int64
# CRSDepTime    int64
# DepDelay      float64
# TaxiOut       float64
# Distance      int64
# CRSArrTime    int64
# ArrDelay      float64
# dtypes: float64(3), int64(7)
# memory usage: 147.8 MB

# %%
df.dropna()
# Out:
#          Month  DayofMonth  DayOfWeek  FlightNum  CRSDepTime  DepDelay  \
# 0            1           3          4        335        1955       8.0
# 1            1           3          4       3231         735      19.0
# 2            1           3          4        448         620       8.0
# 3            1           3          4       3920        1755      34.0
# 4            1           3          4        378        1915      25.0
# 5            1           3          4        509        1830      67.0
# 6            1           3          4        100         700       6.0
# 7            1           3          4       1333        1510      94.0
# 8            1           3          4       2272        1020       9.0
# 9            1           3          4        675        1425      27.0
# 10           1           3          4       1144         745       9.0
# 11           1           3          4          4        1255      28.0
# ...

# %%
df.shape
# Out:
# (1936758, 10)

# %%
# sns.jointplot(df['DepDelay'],df['DayOfWeek'])
#Rough Visualisation of the graph obtained shows that the majority of delays happen during Fridays, followed by Monday

# %%
# sns.jointplot(df['DepDelay'],df['Month'])
#The visualisation below shows that maximum delays happen in december that is during christmas month

# %%
for i in range(len(df['ArrDelay'])):
    if((df['ArrDelay'].values)[i]>15.0):
        (df['ArrDelay'].values)[i] = 1.0
    else:
        (df['ArrDelay'].values)[i] = 0.0

# %%
print(df['ArrDelay'].values)
# Out:
# [0. 0. 0. ... 1. 0. 0.]

# %% [markdown]
# The function written below shows the nuber of tuples which have target values 0 and 1 repectively

# %%
count1 = 0
count0 = 0
for i in range(len(df['ArrDelay'])):
    if((df['ArrDelay'].values)[i] == 0.0):
        count0 = count0+1
    else:
        count1 = count1+1
print(count0,count1)
# Out:
# 721746 1215012

# %% [markdown]
# We can see that the dataset is **SKEWED** with a difference of 493266 tuples.

# %%
1215012-721746
# Out:
# 493266

# %% [markdown]
# The method written down below will help remove the extra tuples with value 1.0, resulting in a balanced dataset

# %%
indexes = []
for i in range(len(df['ArrDelay'].values)):
    if((df['ArrDelay'].values)[i] == 1.0):
        indexes.append(i)

# %%
new_indexes = (indexes[:493266])

# %%
df = df.drop(new_indexes)

# %%
count1 = 0
count0 = 0
for i in range(len(df['ArrDelay'])):
    if((df['ArrDelay'].values)[i] == 0.0):
        count0 = count0+1
    else:
        count1 = count1+1
print(count0,count1)
# Out:
# 721746 721746

# %%
df.shape
# Out:
# (1443492, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1443492 entries, 0 to 1936757
# Data columns (total 10 columns):
# Month         1443492 non-null int64
# DayofMonth    1443492 non-null int64
# DayOfWeek     1443492 non-null int64
# FlightNum     1443492 non-null int64
# CRSDepTime    1443492 non-null int64
# DepDelay      1443492 non-null float64
# TaxiOut       1443037 non-null float64
# Distance      1443492 non-null int64
# CRSArrTime    1443492 non-null int64
# ArrDelay      1443492 non-null float64
# dtypes: float64(3), int64(7)
# memory usage: 121.1 MB

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1443037, 10)

# %%
X = df[['Month', 'DayofMonth', 'DayOfWeek','FlightNum','CRSDepTime', 'DepDelay', 'TaxiOut', 'Distance','CRSArrTime',]]
y = df['ArrDelay']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
pred = lr.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.89    216008
#          1.0       0.91      0.84      0.88    216904
#
#    micro avg       0.88      0.88      0.88    432912
#    macro avg       0.88      0.88      0.88    432912
# weighted avg       0.88      0.88      0.88    432912
#
# [[198477  17531]
#  [ 33947 182957]]
